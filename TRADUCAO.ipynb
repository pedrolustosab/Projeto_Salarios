# %%
import json
from functools import reduce

# %%
def carrega_dados(path:str) -> list[dict]:
    try:
        with open(path, 'r') as arquivo: # abre o arquivo especificado pelo caminho path no modo de leitura ('r')
            dados = arquivo.read()
            return json.loads(dados)
    except FileNotFoundError: # ocorre quando o arquivo especificado em open() não é encontrado
        return []

# %%
# Carregando os dados
dados = carrega_dados('salaries_id.json')
print(json.dumps(dados[50], indent=2))
# Out:
# {
#   "ano_de_trabalho": "2023",
#   "nivel_de_experiencia": "SE",
#   "tipo_de_emprego": "FT",
#   "cargo": "Data Engineer",
#   "salario_em_usd": "205500",
#   "residencia_do_funcionario": "US",
#   "localizacao_da_empresa": "US",
#   "tamanho_da_empresa": "M",
#   "id": 51
# }

# %%
print(f"Linhas atribuídas no projeto: {len(dados)}")
# Out:
# Linhas atribuídas no projeto: 8805

# %%
tipo_contrato = list(set(dado['employment_type'] for dado in dados))
# exibe a lista dos tipos de contratos
print(tipo_contrato)
# Out:
# ['FL', 'CT', 'FT', 'PT']

# %%
anos_unicos = list(set(dado['work_year'] for dado in dados))
# Exibe a lista de anos únicos
print(anos_unicos)
# Out:
# ['2021', '2023', '2020', '2022']

# %%
trabalho_remoto = list(set(dado['remote_ratio'] for dado in dados))
# Exibe a lista de trabalho remoto
print(trabalho_remoto)
# Out:
# [0, 50, 100]

# %%
tamanho_empresa = list(set(dado['company_size'] for dado in dados))
# Exibe a lista de tamanho da empresa
print(tamanho_empresa)
# Out:
# ['L', 'M', 'S']

# %%
cargos = list(set(dado['job_title'] for dado in dados))
# Exibe a lista de tamanho da empresa
print(json.dumps(cargos, indent= 2))

print(len(cargos))
# Out:
# [
#   "Applied Machine Learning Engineer",
#   "Data DevOps Engineer",
#   "Machine Learning Software Engineer",
#   "Decision Scientist",
#   "Business Intelligence Engineer",
#   "Data Manager",
#   "Machine Learning Engineer",
#   "Data Architect",
#   "Applied Machine Learning Scientist",
#   "Business Intelligence Consultant",
#   "Consultant Data Engineer",
#   "Analytics Engineering Manager",
#   "Marketing Data Analyst",
#   "Data Integration Specialist",
#   "Director of Data Science",
#   "Applied Data Scientist",
#   "Data Analytics Lead",
#   "Finance Data Analyst",
#   "Research Engineer",
#   "Data Science Consultant",
#   "Lead Data Analyst",
#   "Data Analytics Manager",
#   "Data Analytics Engineer",
#   "Data Visualization Analyst",
#   "Lead Data Engineer",
#   "Head of Machine Learning",
#   "Data Management Specialist",
#   "Data Modeler",
#   "Business Intelligence Manager",
#   "BI Developer",
#   "ML Engineer",
#   "Product Data Analyst",
#   "Research Scientist",
#   "Data Science Practitioner",
#   "Data Strategy Manager",
#   "Data Engineer",
#   "Data Analytics Specialist",
#   "Cloud Data Engineer",
#   "ETL Engineer",
#   "Data Scientist Lead",
#   "Principal Data Scientist",
#   "Data Science Tech Lead",
#   "Data Operations Specialist",
#   "Data Science Engineer",
#   "Analytics Engineer",
#   "AI Engineer",
#   "Data Specialist",
#   "Data Operations Analyst",
#   "Data Quality Analyst",
#   "Machine Learning Developer",
#   "AI Programmer",
#   "Machine Learning Operations Engineer",
#   "Software Data Engineer",
#   "Computer Vision Engineer",
#   "Business Data Analyst",
#   "Data Developer",
#   "Power BI Developer",
#   "Machine Learning Research Engineer",
#   "Data Product Manager",
#   "Lead Machine Learning Engineer",
#   "Data Scientist",
#   "Data Analytics Consultant",
#   "Principal Data Architect",
#   "AI Developer",
#   "Machine Learning Researcher",
#   "Marketing Data Engineer",
#   "Data Science Manager",
#   "Machine Learning Scientist",
#   "Business Intelligence Specialist",
#   "Data Visualization Specialist",
#   "ETL Developer",
#   "Lead Data Scientist",
#   "Head of Data Science",
#   "Cloud Database Engineer",
#   "Data Science Lead",
#   "Cloud Data Architect",
#   "Machine Learning Manager",
#   "Staff Data Analyst",
#   "Data Operations Engineer",
#   "Autonomous Vehicle Technician",
#   "AI Architect",
#   "Data Visualization Engineer",
#   "Machine Learning Infrastructure Engineer",
#   "Data Quality Engineer",
#   "Data Analyst",
#   "AWS Data Architect",
#   "Business Intelligence Analyst",
#   "Azure Data Engineer",
#   "Financial Data Analyst",
#   "Computer Vision Software Engineer",
#   "Data Science Director",
#   "AI Scientist",
#   "Big Data Engineer",
#   "Machine Learning Specialist",
#   "BI Data Analyst",
#   "Sales Data Analyst",
#   "Manager Data Management",
#   "Applied Scientist",
#   "Insight Analyst",
#   "Data Lead",
#   "Managing Director Data Science",
#   "Data Modeller",
#   "Research Analyst",
#   "Data Infrastructure Engineer",
#   "Compliance Data Analyst",
#   "Data Operations Manager",
#   "NLP Engineer",
#   "AI Research Engineer",
#   "Staff Machine Learning Engineer",
#   "Head of Data",
#   "Principal Machine Learning Engineer",
#   "Deep Learning Researcher",
#   "Business Intelligence Developer",
#   "Business Intelligence Data Analyst",
#   "Data Integration Engineer",
#   "Principal Data Analyst",
#   "BI Analyst",
#   "Deep Learning Engineer",
#   "MLOps Engineer",
#   "Data Strategist",
#   "Staff Data Scientist",
#   "BI Data Engineer",
#   "Principal Data Engineer",
#   "Big Data Architect"
# ]
# 124

# %%
traducao = {
    'work_year': 'ano_de_trabalho',
    'experience_level': 'nivel_de_experiencia',
    'employment_type': 'tipo_de_emprego',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda_do_salario',
    'salary_in_usd': 'salario_em_usd',
    'employee_residence': 'residencia_do_funcionario',
    'remote_ratio': 'trabalho_remoto',
    'company_location': 'localizacao_da_empresa',
    'company_size': 'tamanho_da_empresa',
}

# Traduzindo o conjunto de dados
dados_traduzidos = [{traducao[chave]: valor for chave, valor in dado.items()} for dado in dados]

# Exibindo os dados traduzidos
print(json.dumps(dados_traduzidos[1:50],indent=2 ))
# Out:
# [
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "EX",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Science Director",
#     "salario": "190000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "190000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "MI",
#     "tipo_de_emprego": "FT",
#     "cargo": "Business Intelligence Engineer",
#     "salario": "35000",
#     "moeda_do_salario": "GBP",
#     "salario_em_usd": "43064",
#     "residencia_do_funcionario": "GB",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "GB",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "MI",
#     "tipo_de_emprego": "FT",
#     "cargo": "Business Intelligence Engineer",
#     "salario": "35000",
#     "moeda_do_salario": "GBP",
#     "salario_em_usd": "43064",
#     "residencia_do_funcionario": "GB",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "GB",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Machine Learning Engineer",
#     "salario": "245700",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "245700",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Machine Learning Engineer",
#     "salario": "132300",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "132300",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "MI",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Specialist",
#     "salario": "90000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "90000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "MI",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Specialist",
#     "salario": "80000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "80000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Machine Learning Engineer",
#     "salario": "212000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "212000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Machine Learning Engineer",
#     "salario": "93300",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "93300",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "MI",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Scientist",
#     "salario": "212000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "212000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "MI",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Scientist",
#     "salario": "93300",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "93300",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "ML Engineer",
#     "salario": "276000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "276000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "ML Engineer",
#     "salario": "174000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "174000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "MI",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Engineer",
#     "salario": "133000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "133000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "MI",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Engineer",
#     "salario": "58300",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "58300",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "145640",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "145640",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "84400",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "84400",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Engineer",
#     "salario": "300000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "300000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Engineer",
#     "salario": "195000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "195000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Architect",
#     "salario": "190000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "190000",
#     "residencia_do_funcionario": "CA",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "CA",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Architect",
#     "salario": "107500",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "107500",
#     "residencia_do_funcionario": "CA",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "CA",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "105000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "105000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "75000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "75000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "140000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "140000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "98000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "98000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Machine Learning Engineer",
#     "salario": "204500",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "204500",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Machine Learning Engineer",
#     "salario": "142200",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "142200",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Scientist",
#     "salario": "236160",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "236160",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Scientist",
#     "salario": "159408",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "159408",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "115000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "115000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "85000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "85000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Product Manager",
#     "salario": "145000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "145000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Product Manager",
#     "salario": "120000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "120000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "120350",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "120350",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "74400",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "74400",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "158494",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "158494",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Analyst",
#     "salario": "88052",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "88052",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Analytics Engineer",
#     "salario": "181500",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "181500",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Analytics Engineer",
#     "salario": "127000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "127000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "MI",
#     "tipo_de_emprego": "FT",
#     "cargo": "Machine Learning Engineer",
#     "salario": "300000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "300000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "MI",
#     "tipo_de_emprego": "FT",
#     "cargo": "Machine Learning Engineer",
#     "salario": "260000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "260000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Scientist",
#     "salario": "258000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "258000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Scientist",
#     "salario": "171000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "171000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "EN",
#     "tipo_de_emprego": "FL",
#     "cargo": "Business Intelligence Consultant",
#     "salario": "500000",
#     "moeda_do_salario": "GBP",
#     "salario_em_usd": "615201",
#     "residencia_do_funcionario": "IN",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "IN",
#     "tamanho_da_empresa": "S"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "EN",
#     "tipo_de_emprego": "FT",
#     "cargo": "BI Data Analyst",
#     "salario": "25000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "25000",
#     "residencia_do_funcionario": "UA",
#     "trabalho_remoto": 100,
#     "localizacao_da_empresa": "NL",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Scientist",
#     "salario": "200000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "200000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Data Scientist",
#     "salario": "150000",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "150000",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Machine Learning Engineer",
#     "salario": "225300",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "225300",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   },
#   {
#     "ano_de_trabalho": "2023",
#     "nivel_de_experiencia": "SE",
#     "tipo_de_emprego": "FT",
#     "cargo": "Machine Learning Engineer",
#     "salario": "197400",
#     "moeda_do_salario": "USD",
#     "salario_em_usd": "197400",
#     "residencia_do_funcionario": "US",
#     "trabalho_remoto": 0,
#     "localizacao_da_empresa": "US",
#     "tamanho_da_empresa": "M"
#   }
# ]

# %%
niveis_experiencia = {
    'SE': 'Senior',
    'MI': 'Analista',
    'EN': 'Junior',
    'EX': 'Executivo'
}

# Traduzindo os níveis de experiência no conjunto de dados
for dado in dados_traduzidos:
    if 'experience_level' in dado and dado['experience_level'] in niveis_experiencia:
        dado['experience_level'] = niveis_experiencia[dado['experience_level']]

print(json.dumps(dados_traduzidos[0], indent=2))
# Out:
# {
#   "ano_de_trabalho": "2023",
#   "nivel_de_experiencia": "EX",
#   "tipo_de_emprego": "FT",
#   "cargo": "Data Science Director",
#   "salario": "212000",
#   "moeda_do_salario": "USD",
#   "salario_em_usd": "212000",
#   "residencia_do_funcionario": "US",
#   "trabalho_remoto": 0,
#   "localizacao_da_empresa": "US",
#   "tamanho_da_empresa": "M"
# }

# %%
tipos_contratos = {
    'FT': 'Tempo Integral',
    'PT': 'Meio Periodo',
    'FL': 'Flexivel',
    'CL': 'Contrato'
}

for chave, valor in tipos_contratos.copy().items():
    tipos_contratos[chave] = valor

print(json.dumps(tipos_contratos, indent=2))
# Out:
# {
#   "FT": "Tempo Integral",
#   "PT": "Meio Periodo",
#   "FL": "Flexivel",
#   "CL": "Contrato"
# }

# %%
# Definindo as traduções
traducao = {
    'work_year': 'ano_de_trabalho',
    'experience_level': 'nivel_de_experiencia',
    'employment_type': 'tipo_de_emprego',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda_do_salario',
    'salary_in_usd': 'salario_em_usd',
    'employee_residence': 'residencia_do_funcionario',
    'remote_ratio': 'trabalho_remoto',
    'company_location': 'localizacao_da_empresa',
    'company_size': 'tamanho_da_empresa',
}

niveis_experiencia = {
    'SE': 'Senior',
    'MI': 'Analista',
    'EN': 'Junior',
    'EX': 'Executivo'
}

tipos_contratos = {
    'FT': 'Tempo Integral',
    'PT': 'Meio Periodo',
    'FL': 'Flexivel',
    'CL': 'Contrato'
}

# %%
def remover_info(dados_traduzidos, *chaves) -> list[dict]:
    return [{k: v for k, v in d.items() if k not in chaves} for d in dados_traduzidos]

chaves_a_remover = ['moeda_do_salario', 'trabalho_remoto', 'salario',]  # Pode ser uma lista com várias chaves
novos_dados = remover_info(dados_traduzidos, *chaves_a_remover)
print(json.dumps(novos_dados[0:10], indent=4))
# Out:
# [
#     {
#         "ano_de_trabalho": "2023",
#         "nivel_de_experiencia": "EX",
#         "tipo_de_emprego": "FT",
#         "cargo": "Data Science Director",
#         "salario_em_usd": "212000",
#         "residencia_do_funcionario": "US",
#         "localizacao_da_empresa": "US",
#         "tamanho_da_empresa": "M"
#     },
#     {
#         "ano_de_trabalho": "2023",
#         "nivel_de_experiencia": "EX",
#         "tipo_de_emprego": "FT",
#         "cargo": "Data Science Director",
#         "salario_em_usd": "190000",
#         "residencia_do_funcionario": "US",
#         "localizacao_da_empresa": "US",
#         "tamanho_da_empresa": "M"
#     },
#     {
#         "ano_de_trabalho": "2023",
#         "nivel_de_experiencia": "MI",
#         "tipo_de_emprego": "FT",
#         "cargo": "Business Intelligence Engineer",
#         "salario_em_usd": "43064",
#         "residencia_do_funcionario": "GB",
#         "localizacao_da_empresa": "GB",
#         "tamanho_da_empresa": "M"
#     },
#     {
#         "ano_de_trabalho": "2023",
#         "nivel_de_experiencia": "MI",
#         "tipo_de_emprego": "FT",
#         "cargo": "Business Intelligence Engineer",
#         "salario_em_usd": "43064",
#         "residencia_do_funcionario": "GB",
#         "localizacao_da_empresa": "GB",
#         "tamanho_da_empresa": "M"
#     },
#     {
#         "ano_de_trabalho": "2023",
#         "nivel_de_experiencia": "SE",
#         "tipo_de_emprego": "FT",
#         "cargo": "Machine Learning Engineer",
#         "salario_em_usd": "245700",
#         "residencia_do_funcionario": "US",
#         "localizacao_da_empresa": "US",
#         "tamanho_da_empresa": "M"
#     },
#     {
#         "ano_de_trabalho": "2023",
#         "nivel_de_experiencia": "SE",
#         "tipo_de_emprego": "FT",
#         "cargo": "Machine Learning Engineer",
#         "salario_em_usd": "132300",
#         "residencia_do_funcionario": "US",
#         "localizacao_da_empresa": "US",
#         "tamanho_da_empresa": "M"
#     },
#     {
#         "ano_de_trabalho": "2023",
#         "nivel_de_experiencia": "MI",
#         "tipo_de_emprego": "FT",
#         "cargo": "Data Specialist",
#         "salario_em_usd": "90000",
#         "residencia_do_funcionario": "US",
#         "localizacao_da_empresa": "US",
#         "tamanho_da_empresa": "M"
#     },
#     {
#         "ano_de_trabalho": "2023",
#         "nivel_de_experiencia": "MI",
#         "tipo_de_emprego": "FT",
#         "cargo": "Data Specialist",
#         "salario_em_usd": "80000",
#         "residencia_do_funcionario": "US",
#         "localizacao_da_empresa": "US",
#         "tamanho_da_empresa": "M"
#     },
#     {
#         "ano_de_trabalho": "2023",
#         "nivel_de_experiencia": "SE",
#         "tipo_de_emprego": "FT",
#         "cargo": "Machine Learning Engineer",
#         "salario_em_usd": "212000",
#         "residencia_do_funcionario": "US",
#         "localizacao_da_empresa": "US",
#         "tamanho_da_empresa": "M"
#     },
#     {
#         "ano_de_trabalho": "2023",
#         "nivel_de_experiencia": "SE",
#         "tipo_de_emprego": "FT",
#         "cargo": "Machine Learning Engineer",
#         "salario_em_usd": "93300",
#         "residencia_do_funcionario": "US",
#         "localizacao_da_empresa": "US",
#         "tamanho_da_empresa": "M"
#     }
# ]

# %%
def filtro_ano(item, opc='2023') -> list[dict]:
    try:
        if 'ano_de_trabalho' in item and item['ano_de_trabalho'] == opc:
            return item
        else:
            raise ValueError('Filtro de ano inválido.')
    except Exception as e:
        raise ValueError(f'Erro no filtro de ano: {e}')

def filtro_experiencia(item, opc) -> list[dict]:
    try:
        if 'nivel_de_experiencia' in item and item['nivel_de_experiencia'] == opc:
            return item
        else:
            raise ValueError('Filtro de experiência inválido.')
    except Exception as e:
        raise ValueError(f'Erro no filtro de experiência: {e}')


def filtro_tipo_trabalho(item, opc) -> list[dict]:
    try:
        if 'cargo' in item and item['cargo'] == opc:
            return item
        else:
            raise ValueError('Filtro de tipo de trabalho inválido.')
    except Exception as e:
        raise ValueError(f'Erro no filtro de tipo de trabalho: {e}')

def filtro_salario(item, opc) -> list[dict]:
    try:
        if 'salario_em_usd' in item and item['salario_em_usd'] == opc:
            return item
        else:
            raise ValueError('Filtro de salário inválido.')
    except Exception as e:
        raise ValueError(f'Erro no filtro de salário: {e}')

def filtro_localizacao_funcionario(item, opc) -> list[dict]:
    try:
        if 'residencia_do_funcionario' in item and item['residencia_do_funcionario'] == opc:
            return item
        else:
            raise ValueError('Filtro de localização do funcionário inválido.')
    except Exception as e:
        raise ValueError(f'Erro no filtro de localização do funcionário: {e}')


def filtro_localizacao_empresa(item, opc) -> list[dict]:
    try:
        if 'localizacao_da_empresa' in item and item['localizacao_da_empresa'] == opc:
            return item
        else:
            raise ValueError('Filtro de localização da empresa inválido.')
    except Exception as e:
        raise ValueError(f'Erro no filtro de localização da empresa: {e}')

def filtro_tamanho_empresa(item, opc) -> list[dict]:
    try:
        if 'tamanho_da_empresa' in item and item['tamanho_da_empresa'] == opc:
            return item
        else:
            raise ValueError('Filtro de tamanho da empresa inválido.')
    except Exception as e:
        raise ValueError(f'Erro no filtro de tamanho da empresa: {e}')

# %%
def obter_ano(anos, msg='Anos'):
    while True:
        try:
            ano = input(f"{msg} ({' | '.join(anos_unicos)}): ")
            if ano in anos_unicos:
                break
            else:
                raise ValueError('Entrada Inválida! Dado não está na lista.')
        except ValueError as e:
            print(f'Erro: {e}\n')

    return ano

# %%
cargos_ds = ['Director of Data Science', 'Data Science Consultant', 'Data Science Tech Lead', 'Managing Director Data Science', 'Data Science Lead', 'Data Science Practitioner', 'Data Science Manager', 'Head of Data Science', 'Data Science Director', 'Data Science Engineer']

def obter_cargo(cargos_ds, msg='Cargos'):
    while True:
        try:
            cargo = input(f"{msg} ({' | '.join(cargos_ds)}): ")
            if cargo in cargos_ds:
                break
            else:
                raise ValueError('Entrada Inválida! Dado não está na lista.')
        except ValueError as e:
            print(f'Erro: {e}\n')

    return cargos_ds

# %%
m = obter_cargo(cargos_ds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-a4d27ec3af09> in <cell line: 1>()
# ----> 1 m = obter_cargo(cargos_ds)
#
# NameError: name 'cargos_ds' is not defined
